# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import time
import os
import requests 

import pandas as pd
from pandas import DataFrame, read_csv
import scipy as sc
import numpy as np

import re

import statsmodels.formula.api as sm

import matplotlib.pyplot as plt 
plt.style.use('ggplot')
# %matplotlib inline  
plt.rcParams['figure.figsize'] = (10, 6)

# %%
careerAVGPlayer = pd.read_csv('Data/CSV Files/Database/careerAVGPlayer.csv')
del careerAVGPlayer['Colleges']
careerAVGPlayer
# Out:
#              ID               Player  Years    From      To  Ht(cm)  Wt(kg)  \
# 0     greenac01           A.C. Green   16.0  1986.0  2001.0  205.74   220.0
# 1     bramlaj01        A.J. Bramlett    1.0  2000.0  2000.0  208.28   227.0
# 2     engliaj01         A.J. English    2.0  1991.0  1992.0  190.50   175.0
# 3     guytoaj01          A.J. Guyton    3.0  2001.0  2003.0  185.42   180.0
# 4     hammoaj01         A.J. Hammons    1.0  2017.0  2017.0  213.36   260.0
# 5     priceaj01           A.J. Price    6.0  2010.0  2015.0  187.96   181.0
# 6     wyndeaj01          A.J. Wynder    1.0  1991.0  1991.0  187.96   180.0
# 7     brookaa01         Aaron Brooks   10.0  2008.0  2018.0  182.88   161.0
# 8     gordoaa01         Aaron Gordon    5.0  2015.0  2019.0  205.74   220.0
# 9      grayaa01           Aaron Gray    7.0  2008.0  2014.0  213.36   270.0
# 10    harriaa01       Aaron Harrison    3.0  2016.0  2018.0  198.12   210.0
# ...

# %%
collegeCareerTotPlayer = pd.read_csv('Data/CSV Files/Database/FullNBAPlayersColleges.csv')
collegeCareerTotPlayer = collegeCareerTotPlayer[['ID', 'Colleges']]
collegeCareerTotPlayer.shape
# Out:
# (2505, 2)

# %%
careerAVGPlayer = pd.merge(careerAVGPlayer, collegeCareerTotPlayer, on='ID', how='outer')
careerAVGPlayer
# Out:
#              ID               Player  Years    From      To  Ht(cm)  Wt(kg)  \
# 0     greenac01           A.C. Green   16.0  1986.0  2001.0  205.74   220.0
# 1     bramlaj01        A.J. Bramlett    1.0  2000.0  2000.0  208.28   227.0
# 2     engliaj01         A.J. English    2.0  1991.0  1992.0  190.50   175.0
# 3     guytoaj01          A.J. Guyton    3.0  2001.0  2003.0  185.42   180.0
# 4     hammoaj01         A.J. Hammons    1.0  2017.0  2017.0  213.36   260.0
# 5     priceaj01           A.J. Price    6.0  2010.0  2015.0  187.96   181.0
# 6     wyndeaj01          A.J. Wynder    1.0  1991.0  1991.0  187.96   180.0
# 7     brookaa01         Aaron Brooks   10.0  2008.0  2018.0  182.88   161.0
# 8     gordoaa01         Aaron Gordon    5.0  2015.0  2019.0  205.74   220.0
# 9      grayaa01           Aaron Gray    7.0  2008.0  2014.0  213.36   270.0
# 10    harriaa01       Aaron Harrison    3.0  2016.0  2018.0  198.12   210.0
# ...

# %%
outsideUS = pd.read_csv('Data/CSV Files/Database/outsideUSDF.csv')
outsideUS = outsideUS[['ID', 'Colleges']]
outsideUS
# Out:
#             ID                          Colleges
# 0    djordal01                            Serbia
# 1    abrinal01                             Spain
# 2    garcial01                            Brazil
# 3    volkoal01                           Ukraine
# 4    shvedal01                            Russia
# 5    ajincal01                            France
# 6    varejan01                            Brazil
# 7    blatcan01                       Philippines
# 8    bargnan01                             Italy
# 9    glynian01                            Greece
# 10   kirilan01                            Russia
# 11   guibean01                              Cuba
# 12   nocioan01                         Argentina
# 13   biedran01                            Latvia
# 14   rigauan01                            France
# 15   fotsian01                            Greece
# 16   macijar01                         Lithuania
# 17   sabonar01                         Lithuania
# ...

# %%
careerAVGPlayer = pd.merge(careerAVGPlayer, outsideUS, on='ID', how = 'outer')
careerAVGPlayer
# Out:
#              ID               Player  Years    From      To  Ht(cm)  Wt(kg)  \
# 0     greenac01           A.C. Green   16.0  1986.0  2001.0  205.74   220.0
# 1     bramlaj01        A.J. Bramlett    1.0  2000.0  2000.0  208.28   227.0
# 2     engliaj01         A.J. English    2.0  1991.0  1992.0  190.50   175.0
# 3     guytoaj01          A.J. Guyton    3.0  2001.0  2003.0  185.42   180.0
# 4     hammoaj01         A.J. Hammons    1.0  2017.0  2017.0  213.36   260.0
# 5     priceaj01           A.J. Price    6.0  2010.0  2015.0  187.96   181.0
# 6     wyndeaj01          A.J. Wynder    1.0  1991.0  1991.0  187.96   180.0
# 7     brookaa01         Aaron Brooks   10.0  2008.0  2018.0  182.88   161.0
# 8     gordoaa01         Aaron Gordon    5.0  2015.0  2019.0  205.74   220.0
# 9      grayaa01           Aaron Gray    7.0  2008.0  2014.0  213.36   270.0
# 10    harriaa01       Aaron Harrison    3.0  2016.0  2018.0  198.12   210.0
# ...
